# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import matplotlib.pyplot as plt


# Google API Key
from config import gkey
from config2 import ykey

# %%
zipcode_data = pd.read_csv ("./uszips.csv")
zipcode_data.head()
# Out:
#      zip      lat       lng              city state_id   state_name  zcta  \
# 0    951  18.4284  -66.2566          Toa Baja       PR  Puerto Rico  True
# 1  96863  21.4484 -157.7623  Mcbh Kaneohe Bay       HI       Hawaii  True
# 2  34141  25.9723  -81.0936           Ochopee       FL      Florida  True
# 3  78060  28.4469  -98.1071          Oakville       TX        Texas  True
# 4  78144  28.9551  -97.8880       Panna Maria       TX        Texas  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN          35     32.5        72137    Toa Baja
# 1          NaN          52    708.1        15003    Honolulu
# 2          NaN         232      0.1        12021     Collier
# 3          NaN          37     36.3        48297    Live Oak
# 4          NaN          45      7.7        48255      Karnes
#
#              all_county_weights  imprecise  military             timezone
# 0                 {'72137':100}      False     False  America/Puerto_Rico
# 1                 {'15003':100}      False     False     Pacific/Honolulu
# 2  {'12021':97.41,'12087':2.59}      False     False     America/New_York
# 3                 {'48297':100}      False     False      America/Chicago
# 4                 {'48255':100}      False     False      America/Chicago

# %%
zipcode_gym_data = pd.read_csv ("./zipcode gym count.csv")
zipcode_gym_data.head()
# Out:
#    Unnamed: 0 state_id    zip      lat       lng  gym count
# 0           7       LA  70801  30.4497  -91.1859       22.0
# 1          15       NM  88004  32.2231 -106.9874        0.0
# 2          17       NM  88055  32.7382 -108.7339        0.0
# 3          20       NM  88262  33.1329 -103.4259        0.0
# 4          22       SC  29899  33.9279  -82.2507        0.0

# %%
county_gym_data = pd.merge (zipcode_gym_data, zipcode_data, on="zip", how="left")
county_gym_data.head()
# Out:
#    Unnamed: 0 state_id_x    zip    lat_x     lng_x  gym count    lat_y  \
# 0           7         LA  70801  30.4497  -91.1859       22.0  30.4497
# 1          15         NM  88004  32.2231 -106.9874        0.0  32.2231
# 2          17         NM  88055  32.7382 -108.7339        0.0  32.7382
# 3          20         NM  88262  33.1329 -103.4259        0.0  33.1329
# 4          22         SC  29899  33.9279  -82.2507        0.0  33.9279
#
#       lng_y         city state_id_y        ...         zcta  parent_zcta  \
# 0  -91.1859  Baton Rouge         LA        ...         True          NaN
# 1 -106.9874   Las Cruces         NM        ...         True          NaN
# 2 -108.7339      Redrock         NM        ...         True          NaN
# 3 -103.4259     Mcdonald         NM        ...         True          NaN
# 4  -82.2507   Mc Cormick         SC        ...         True          NaN
#
#    population  density  county_fips       county_name all_county_weights  \
# 0          13     38.7        22033  East Baton Rouge      {'22033':100}
# 1         699      6.9        35013          Doña Ana      {'35013':100}
# 2          37      0.0        35017             Grant      {'35017':100}
# 3          30      0.2        35025               Lea      {'35025':100}
# 4        1244   1272.9        45065         McCormick      {'45065':100}
#
#   imprecise  military          timezone
# 0     False     False   America/Chicago
# 1     False     False    America/Denver
# 2     False     False    America/Denver
# 3     False     False    America/Denver
# 4     False     False  America/New_York
#
# [5 rows x 21 columns]

# %%
county_gym_data = county_gym_data[["state_id_x", "zip", "gym count", "county_name"]]
county_gym_data.head()
# Out:
#   state_id_x    zip  gym count       county_name
# 0         LA  70801       22.0  East Baton Rouge
# 1         NM  88004        0.0          Doña Ana
# 2         NM  88055        0.0             Grant
# 3         NM  88262        0.0               Lea
# 4         SC  29899        0.0         McCormick

# %%
county_gym_data_2 = county_gym_data.groupby(["state_id_x","county_name"])

county_gym_data_3 = county_gym_data_2["gym count"].sum()
county_gym_data_3
# Out:
# state_id_x  county_name
# AK          Aleutians East              0.0
#             Aleutians West              0.0
#             Anchorage                  98.0
#             Bethel                      0.0
#             Bristol Bay                 0.0
#             Denali                      0.0
#             Dillingham                  0.0
#             Fairbanks North Star        6.0
#             Haines                      0.0
#             Hoonah-Angoon               0.0
#             Juneau                      4.0
#             Kenai Peninsula             0.0
#             Ketchikan Gateway           0.0
#             Kodiak Island               0.0
#             Lake and Peninsula          0.0
#             Matanuska-Susitna           0.0
#             Nome                        0.0
#             North Slope                 0.0
#             Northwest Arctic            0.0
#             Petersburg                  0.0
#             Prince of Wales-Hyder       0.0
#             Sitka                       0.0
#             Skagway                     0.0
#             Southeast Fairbanks         0.0
#             Valdez-Cordova              0.0
#             Wade Hampton                0.0
#             Wrangell                    0.0
#             Yakutat                     0.0
#             Yukon-Koyukuk               0.0
# AR          Arkansas                    0.0
#                                       ...
# SC          Lee                         0.0
#             Lexington                  45.0
#             Marion                      0.0
#             Marlboro                    2.0
#             McCormick                   0.0
#             Newberry                    2.0
#             Oconee                      0.0
#             Orangeburg                  6.0
#             Pickens                     7.0
#             Richland                  228.0
#             Saluda                      0.0
#             Spartanburg                56.0
#             Sumter                      2.0
#             Union                       0.0
#             Williamsburg                0.0
#             York                       69.0
# VT          Addison                   710.0
#             Bennington                865.0
#             Caledonia                 195.0
#             Chittenden                337.0
#             Essex                     950.0
#             Franklin                  993.0
#             Grand Isle                 30.0
#             Lamoille                   96.0
#             Orange                   1424.0
#             Orleans                    68.0
#             Rutland                   570.0
#             Washington                505.0
#             Windham                   283.0
#             Windsor                  1915.0
# Name: gym count, Length: 322, dtype: float64

# %%
county_gym_data_3.to_csv("county gym count.csv")

# %%
gym_count_chart = county_gym_data_3.plot(kind='bar')

# %%
# county_name_list = county_gym_data["county_name"]
# county_name_list = county_name_list.drop_duplicates()
# county_name_list = county_name_list.tolist()
# len(county_name_list)

# %%
# gym_count_county = []
# county_in_state =[]
# for county in county_name_list:
#     zipcode_county_data = county_gym_data[(county_gym_data["county_name"]==county)].sum()["gym count"]
#     gym_count_county.append(zipcode_county_data)
#     county_name_state = county_gym_data[(county_gym_data["county_name"]==county)]["state_id_x"]
    
#     county_in_state.append(county_name_state)
    
    
    
# gym_count_county_df = pd.DataFrame({"state": county_in_state, "county_name": county_name_list, "Total Gym Count County": gym_count_county})

# gym_count_county_df.head()

# %%
county_in_state = []

# %%
# gym_count_county_df = pd.DataFrame({"county_name": county_name_list, "Total Gym Count County": gym_count_county})

# gym_count_county_df

# %%
# gym_count_county_sate_df = pd.merge (gym_count_county_df, county_gym_data, on= "county_name", how="left")
# gym_count_county_sate_df = gym_count_county_sate_df.drop_duplicates()
# gym_count_county_sate_df
